# %%
import torch
version = torch.__version__
print(f"PyTorch version: {version}")
# Out:
# PyTorch version: 2.10.0+cu128

# %%
if torch.cuda.is_available():
    print("CUDA is available. You can use GPU acceleration.")
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is not available. Using CPU.")
# Out:
# CUDA is available. You can use GPU acceleration.
# Using GPU: Tesla T4

# %% [markdown]
# # Creating a Tensor

# %%
a = torch.empty(2,3)
print(a)
# Out:
# tensor([[9.9573e-09, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00]])

# %%
type(a)
# Out:
# torch.Tensor

# %%
torch.zeros(2,3)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
torch.ones(2,3)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
torch.rand(2,3)
# Out:
# tensor([[0.6416, 0.6098, 0.5435],
#         [0.2010, 0.3618, 0.2270]])

# %%
torch.manual_seed(42)
torch.rand(2,3)
# Out:
# tensor([[0.8823, 0.9150, 0.3829],
#         [0.9593, 0.3904, 0.6009]])

# %% [markdown]
# # Tensor Shapes

# %%
x = torch.tensor([1,2,3])
print(x)
# Out:
# tensor([1, 2, 3])

# %%
x.shape
# Out:
# torch.Size([3])

# %% [markdown]
# # Tensor Data Type

# %%
x.dtype
# Out:
# torch.int64

# %%
torch.tensor([1,2,3], dtype=torch.float32)
# Out:
# tensor([1., 2., 3.])

# %%
x.to(torch.float32)
# Out:
# tensor([1., 2., 3.])

# %%
a = torch.rand(2,3)
b = torch.rand(2,3)

# %%
a + b
# Out:
# tensor([[1.1260, 1.3614, 1.6819],
#         [0.5626, 1.8200, 1.1675]])

# %%
a - b
# Out:
# tensor([[-0.6128,  0.2259,  0.1997],
#         [-0.2962,  0.0492,  0.0197]])

# %%
a * b
# Out:
# tensor([[0.2231, 0.4506, 0.6972],
#         [0.0572, 0.8275, 0.3407]])
